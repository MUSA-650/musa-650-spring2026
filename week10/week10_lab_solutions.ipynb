# %% [markdown]
# # Week 10 Lab — Practical Deep Learning: Augmentation, Dropout & Batch Normalization (Solutions)
#
# ---
#
# **What you will build:**
# - A cats-vs-dogs binary classifier using CIFAR-10
# - Observe overfitting on a baseline model
# - Fix it with data augmentation, Dropout, and Batch Normalization
# - Compare training curves across all four models

# %% [markdown]
# ---
# # Part 1 — Setup and Data Loading

# %% [markdown]
# ## Step 1 — Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import (
    Conv2D, MaxPooling2D, Flatten, Dense,
    Dropout, BatchNormalization, Activation
)
from keras._tf_keras.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical

# %% [markdown]
# ## Step 2 — Load CIFAR-10 and Extract Cats & Dogs

# %%
# Load CIFAR-10
(x_train_all, y_train_all), (x_test_all, y_test_all) = cifar10.load_data()

CAT_LABEL = 3
DOG_LABEL = 5

# Extract cats and dogs from training set
train_mask = np.isin(y_train_all.flatten(), [CAT_LABEL, DOG_LABEL])
x_train = x_train_all[train_mask]
y_train_raw = y_train_all[train_mask].flatten()

# Extract cats and dogs from test set
test_mask = np.isin(y_test_all.flatten(), [CAT_LABEL, DOG_LABEL])
x_test = x_test_all[test_mask]
y_test_raw = y_test_all[test_mask].flatten()

# Convert labels to binary: cat=0, dog=1
y_train = (y_train_raw == DOG_LABEL).astype('float32')
y_test  = (y_test_raw  == DOG_LABEL).astype('float32')

print("Training set:", x_train.shape, "| Labels:", y_train.shape)
print("Test set:    ", x_test.shape,  "| Labels:", y_test.shape)
print(f"Cats in train: {np.sum(y_train==0)}, Dogs in train: {np.sum(y_train==1)}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 15s 0us/step
# Training set: (10000, 32, 32, 3) | Labels: (10000,)
# Test set:     (2000, 32, 32, 3) | Labels: (2000,)
# Cats in train: 5000, Dogs in train: 5000

# %% [markdown]
# ## Step 3 — Normalize Pixel Values and Visualize

# %%
# Normalize to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test  = x_test.astype('float32')  / 255.0

print("Pixel range — min:", x_train.min(), "max:", x_train.max())
# Out:
# Pixel range — min: 0.0 max: 1.0

# %%
# Visualize some training images
class_names = ['Cat', 'Dog']
fig, axes = plt.subplots(2, 8, figsize=(14, 4))
for row, label in enumerate([0, 1]):
    imgs = x_train[y_train == label][:8]
    for col, img in enumerate(imgs):
        axes[row, col].imshow(img)
        axes[row, col].set_title(class_names[label], fontsize=8)
        axes[row, col].axis('off')
plt.suptitle('CIFAR-10 Cats (top) and Dogs (bottom)', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Part 2 — Baseline CNN (No Augmentation, No Regularization)

# %% [markdown]
# ## Step 4 — Build the Baseline CNN

# %%
def build_baseline_model():
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
        MaxPooling2D(2,2),
        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D(2,2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    return model

baseline_model = build_baseline_model()
baseline_model.summary()
# Out:
# c:\Users\Henry\Desktop\MUSA6500_Desktop\musa-6500-spring2026-repo\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 314,561 (1.20 MB)
#  Trainable params: 314,561 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 5 — Compile and Train the Baseline Model

# %%
baseline_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_baseline = baseline_model.fit(
    x_train, y_train,
    batch_size=64,
    epochs=20,
    validation_data=(x_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.5798 - loss: 0.6692 - val_accuracy: 0.6535 - val_loss: 0.6317
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6794 - loss: 0.5969 - val_accuracy: 0.6995 - val_loss: 0.5681
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7066 - loss: 0.5618 - val_accuracy: 0.6935 - val_loss: 0.5776
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7321 - loss: 0.5313 - val_accuracy: 0.7220 - val_loss: 0.5320
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7489 - loss: 0.5025 - val_accuracy: 0.7420 - val_loss: 0.5250
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7718 - loss: 0.4728 - val_accuracy: 0.7335 - val_loss: 0.5210
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7861 - loss: 0.4496 - val_accuracy: 0.7485 - val_loss: 0.5194
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7983 - loss: 0.4222 - val_accuracy: 0.7475 - val_loss: 0.5101
# Epoch 9/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8254 - loss: 0.3864 - val_accuracy: 0.7435 - val_loss: 0.5566
# Epoch 10/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8378 - loss: 0.3597 - val_accuracy: 0.7385 - val_loss: 0.5492
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8555 - loss: 0.3210 - val_accuracy: 0.7390 - val_loss: 0.5590
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8737 - loss: 0.2853 - val_accuracy: 0.7505 - val_loss: 0.5959
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8885 - loss: 0.2554 - val_accuracy: 0.7530 - val_loss: 0.6086
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9116 - loss: 0.2155 - val_accuracy: 0.7555 - val_loss: 0.6438
# Epoch 15/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9231 - loss: 0.1891 - val_accuracy: 0.7600 - val_loss: 0.6722
# Epoch 16/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9458 - loss: 0.1468 - val_accuracy: 0.7595 - val_loss: 0.7205
# Epoch 17/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9612 - loss: 0.1143 - val_accuracy: 0.7520 - val_loss: 0.7518
# Epoch 18/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9721 - loss: 0.0930 - val_accuracy: 0.7570 - val_loss: 0.8219
# Epoch 19/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9794 - loss: 0.0731 - val_accuracy: 0.7495 - val_loss: 0.8873
# Epoch 20/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9849 - loss: 0.0564 - val_accuracy: 0.7510 - val_loss: 0.9520

# %% [markdown]
# ## Step 6 — Plot Training Curves and Observe Overfitting

# %%
def plot_history(history, title='Training Curves'):
    """Plot training and validation accuracy and loss."""
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    axes[0].plot(history.history['accuracy'],     label='Train')
    axes[0].plot(history.history['val_accuracy'], label='Validation')
    axes[0].set_title(title + ' — Accuracy')
    axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].spines['top'].set_visible(False); axes[0].spines['right'].set_visible(False)
    
    axes[1].plot(history.history['loss'],     label='Train')
    axes[1].plot(history.history['val_loss'], label='Validation')
    axes[1].set_title(title + ' — Loss')
    axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].spines['top'].set_visible(False); axes[1].spines['right'].set_visible(False)
    
    plt.tight_layout()
    plt.show()

plot_history(history_baseline, 'Baseline CNN (no regularization)')

# %% [markdown]
# **Answer**: Yes, overfitting is clearly visible. Training accuracy climbs toward ~80–85% while validation accuracy plateaus or drops around epoch 10–15. The gap between them is the signature of overfitting — the model is memorizing training data rather than learning generalizable features.

# %% [markdown]
# ---
# # Part 3 — Data Augmentation

# %% [markdown]
# ## Step 7 — Visualize Augmented Cat Images

# %%
aug_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

cat_images = x_train[y_train == 0][:3]

fig, axes = plt.subplots(3, 6, figsize=(13, 7))
for row, cat in enumerate(cat_images):
    axes[row, 0].imshow(cat)
    axes[row, 0].set_title('Original', fontsize=8)
    axes[row, 0].axis('off')
    img_batch = cat.reshape((1,) + cat.shape)
    for col, batch in zip(range(1, 6), aug_datagen.flow(img_batch, batch_size=1)):
        axes[row, col].imshow(np.clip(batch[0], 0, 1))
        axes[row, col].set_title(f'Aug {col}', fontsize=8)
        axes[row, col].axis('off')
plt.suptitle('Cat Images: Original and Augmented Versions', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 8 — Train the Same Model with Augmentation

# %%
aug_model = build_baseline_model()
aug_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

train_gen = aug_datagen.flow(x_train, y_train, batch_size=64)

history_aug = aug_model.fit(
    train_gen,
    steps_per_epoch=len(x_train) // 64,
    epochs=20,
    validation_data=(x_test, y_test),
    verbose=1
)

plot_history(history_aug, 'CNN with Data Augmentation')
# Out:
# Epoch 1/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.5696 - loss: 0.6787 - val_accuracy: 0.6275 - val_loss: 0.6443
# Epoch 2/20
#   1/156 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6406 - loss: 0.6578
# c:\Users\Henry\Desktop\MUSA6500_Desktop\musa-6500-spring2026-repo\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6406 - loss: 0.6578 - val_accuracy: 0.6225 - val_loss: 0.6459
# Epoch 3/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6204 - loss: 0.6482 - val_accuracy: 0.6520 - val_loss: 0.6139
# Epoch 4/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.5654 - val_accuracy: 0.6405 - val_loss: 0.6195
# Epoch 5/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6488 - loss: 0.6261 - val_accuracy: 0.6845 - val_loss: 0.5750
# Epoch 6/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.6333 - val_accuracy: 0.6810 - val_loss: 0.5753
# Epoch 7/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6648 - loss: 0.6126 - val_accuracy: 0.7195 - val_loss: 0.5532
# Epoch 8/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.6736 - val_accuracy: 0.7145 - val_loss: 0.5526
# Epoch 9/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.6731 - loss: 0.6001 - val_accuracy: 0.6980 - val_loss: 0.5673
# Epoch 10/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6562 - loss: 0.5602 - val_accuracy: 0.6950 - val_loss: 0.5758
# Epoch 11/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.6825 - loss: 0.5927 - val_accuracy: 0.7160 - val_loss: 0.5422
# Epoch 12/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.5859 - val_accuracy: 0.7200 - val_loss: 0.5422
# Epoch 13/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6813 - loss: 0.5897 - val_accuracy: 0.7285 - val_loss: 0.5257
# Epoch 14/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6250 - loss: 0.6229 - val_accuracy: 0.7250 - val_loss: 0.5299
# Epoch 15/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.6965 - loss: 0.5745 - val_accuracy: 0.7520 - val_loss: 0.5149
# Epoch 16/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6562 - loss: 0.6738 - val_accuracy: 0.7500 - val_loss: 0.5145
# Epoch 17/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.7066 - loss: 0.5681 - val_accuracy: 0.7440 - val_loss: 0.5142
# Epoch 18/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 0.6710 - val_accuracy: 0.7420 - val_loss: 0.5146
# Epoch 19/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7120 - loss: 0.5571 - val_accuracy: 0.7465 - val_loss: 0.5074
# Epoch 20/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6719 - loss: 0.5768 - val_accuracy: 0.7460 - val_loss: 0.5069

# %% [markdown]
# **Answer**: Augmentation reduces overfitting by making the model see more varied versions of each image. Training accuracy grows more slowly (the problem is harder) while validation accuracy is more stable. The train/val gap is smaller than the baseline.

# %% [markdown]
# ---
# # Part 4 — Adding Dropout

# %% [markdown]
# ## Step 9 — Build a Model with Dropout

# %%
def build_dropout_model():
    model = Sequential([
        Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
        MaxPooling2D(2,2),
        Conv2D(64, (3,3), activation='relu'),
        MaxPooling2D(2,2),
        Dropout(0.25),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

dropout_model = build_dropout_model()
dropout_model.summary()
# Out:
# c:\Users\Henry\Desktop\MUSA6500_Desktop\musa-6500-spring2026-repo\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 314,561 (1.20 MB)
#  Trainable params: 314,561 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Step 10 — Train with Augmentation + Dropout

# %%
dropout_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

train_gen2 = aug_datagen.flow(x_train, y_train, batch_size=64)
history_dropout = dropout_model.fit(
    train_gen2,
    steps_per_epoch=len(x_train) // 64,
    epochs=20,
    validation_data=(x_test, y_test),
    verbose=1
)

plot_history(history_dropout, 'CNN with Augmentation + Dropout')
# Out:
# Epoch 1/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.5603 - loss: 0.6839 - val_accuracy: 0.6480 - val_loss: 0.6476
# Epoch 2/20
#   1/156 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5000 - loss: 0.6971
# c:\Users\Henry\Desktop\MUSA6500_Desktop\musa-6500-spring2026-repo\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5000 - loss: 0.6971 - val_accuracy: 0.6425 - val_loss: 0.6478
# Epoch 3/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6252 - loss: 0.6521 - val_accuracy: 0.5930 - val_loss: 0.6498
# Epoch 4/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5312 - loss: 0.6859 - val_accuracy: 0.6155 - val_loss: 0.6404
# Epoch 5/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6483 - loss: 0.6350 - val_accuracy: 0.6815 - val_loss: 0.5901
# Epoch 6/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6094 - loss: 0.6938 - val_accuracy: 0.6955 - val_loss: 0.5817
# Epoch 7/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6576 - loss: 0.6186 - val_accuracy: 0.6545 - val_loss: 0.6056
# Epoch 8/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7031 - loss: 0.5953 - val_accuracy: 0.6600 - val_loss: 0.6001
# Epoch 9/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6674 - loss: 0.6095 - val_accuracy: 0.7095 - val_loss: 0.5551
# Epoch 10/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6094 - loss: 0.6347 - val_accuracy: 0.7150 - val_loss: 0.5540
# Epoch 11/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - accuracy: 0.6757 - loss: 0.6035 - val_accuracy: 0.7125 - val_loss: 0.5590
# Epoch 12/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8750 - loss: 0.4831 - val_accuracy: 0.7140 - val_loss: 0.5592
# Epoch 13/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6874 - loss: 0.5919 - val_accuracy: 0.7140 - val_loss: 0.5434
# Epoch 14/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5625 - loss: 0.6589 - val_accuracy: 0.6990 - val_loss: 0.5566
# Epoch 15/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - accuracy: 0.6937 - loss: 0.5837 - val_accuracy: 0.7360 - val_loss: 0.5184
# Epoch 16/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.5049 - val_accuracy: 0.7405 - val_loss: 0.5157
# Epoch 17/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.6977 - loss: 0.5752 - val_accuracy: 0.7485 - val_loss: 0.5061
# Epoch 18/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7188 - loss: 0.5607 - val_accuracy: 0.7415 - val_loss: 0.5166
# Epoch 19/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.7051 - loss: 0.5683 - val_accuracy: 0.7520 - val_loss: 0.4998
# Epoch 20/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.5218 - val_accuracy: 0.7505 - val_loss: 0.4969

# %% [markdown]
# ---
# # Part 5 — Adding Batch Normalization

# %% [markdown]
# ## Step 11 — Build a Model with Batch Normalization + Dropout

# %%
def build_bn_model():
    model = Sequential([
        # Block 1
        Conv2D(32, (3,3), input_shape=(32,32,3)),
        BatchNormalization(),
        Activation('relu'),
        MaxPooling2D(2,2),

        # Block 2
        Conv2D(64, (3,3)),
        BatchNormalization(),
        Activation('relu'),
        MaxPooling2D(2,2),
        Dropout(0.25),

        # Dense head
        Flatten(),
        Dense(128),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    return model

bn_model = build_bn_model()
bn_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 315,457 (1.20 MB)
#  Trainable params: 315,009 (1.20 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ## Step 12 — Train with Augmentation + BatchNorm + Dropout

# %%
bn_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

train_gen3 = aug_datagen.flow(x_train, y_train, batch_size=64)
history_bn = bn_model.fit(
    train_gen3,
    steps_per_epoch=len(x_train) // 64,
    epochs=20,
    validation_data=(x_test, y_test),
    verbose=1
)

plot_history(history_bn, 'CNN with Augmentation + BatchNorm + Dropout')
# Out:
# Epoch 1/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.5757 - loss: 0.7494 - val_accuracy: 0.5940 - val_loss: 0.6680
# Epoch 2/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6719 - loss: 0.6444 - val_accuracy: 0.5965 - val_loss: 0.6668
# Epoch 3/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.6268 - loss: 0.6625 - val_accuracy: 0.5975 - val_loss: 0.6456
# Epoch 4/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7031 - loss: 0.5859 - val_accuracy: 0.5985 - val_loss: 0.6475
# Epoch 5/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6483 - loss: 0.6266 - val_accuracy: 0.6985 - val_loss: 0.5801
# Epoch 6/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6719 - loss: 0.6048 - val_accuracy: 0.6960 - val_loss: 0.5816
# Epoch 7/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6709 - loss: 0.6046 - val_accuracy: 0.6100 - val_loss: 0.6585
# Epoch 8/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6094 - loss: 0.6348 - val_accuracy: 0.6045 - val_loss: 0.6690
# Epoch 9/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6824 - loss: 0.5935 - val_accuracy: 0.7170 - val_loss: 0.5386
# Epoch 10/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6094 - loss: 0.6072 - val_accuracy: 0.7195 - val_loss: 0.5381
# Epoch 11/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6956 - loss: 0.5801 - val_accuracy: 0.7325 - val_loss: 0.5166
# Epoch 12/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6406 - loss: 0.6248 - val_accuracy: 0.7270 - val_loss: 0.5350
# Epoch 13/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - accuracy: 0.6935 - loss: 0.5774 - val_accuracy: 0.7085 - val_loss: 0.5563
# Epoch 14/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 0.5857 - val_accuracy: 0.7180 - val_loss: 0.5417
# Epoch 15/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7018 - loss: 0.5681 - val_accuracy: 0.7300 - val_loss: 0.5349
# Epoch 16/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6250 - loss: 0.6231 - val_accuracy: 0.7340 - val_loss: 0.5255
# Epoch 17/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7054 - loss: 0.5606 - val_accuracy: 0.7085 - val_loss: 0.5589
# Epoch 18/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7969 - loss: 0.5270 - val_accuracy: 0.7160 - val_loss: 0.5588
# Epoch 19/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.7136 - loss: 0.5544 - val_accuracy: 0.7210 - val_loss: 0.5450
# Epoch 20/20
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6406 - loss: 0.6118 - val_accuracy: 0.7310 - val_loss: 0.5197

# %% [markdown]
# ---
# # Part 6 — Compare All Models

# %% [markdown]
# ## Step 13 — Side-by-Side Validation Accuracy Comparison

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(history_baseline.history['val_accuracy'], label='Baseline',               linestyle='--')
ax.plot(history_aug.history['val_accuracy'],      label='+ Augmentation',         linestyle='-')
ax.plot(history_dropout.history['val_accuracy'],  label='+ Augmentation+Dropout', linestyle='-.')
ax.plot(history_bn.history['val_accuracy'],       label='+ Aug+BN+Dropout',       linestyle=':')

ax.set_xlabel('Epoch')
ax.set_ylabel('Validation Accuracy')
ax.set_title('Validation Accuracy: All Four Models')
ax.legend()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.show()

print("Final validation accuracies (last epoch):")
print(f"  Baseline:               {history_baseline.history['val_accuracy'][-1]:.3f}")
print(f"  + Augmentation:         {history_aug.history['val_accuracy'][-1]:.3f}")
print(f"  + Aug + Dropout:        {history_dropout.history['val_accuracy'][-1]:.3f}")
print(f"  + Aug + BN + Dropout:   {history_bn.history['val_accuracy'][-1]:.3f}")
# Out:
# Final validation accuracies (last epoch):
#   Baseline:               0.751
#   + Augmentation:         0.746
#   + Aug + Dropout:        0.751
#   + Aug + BN + Dropout:   0.731

# %% [markdown]
# ---
# # Part 7 — Reflection (Model Answers)
#
# **1. Which model shows the most overfitting?**
# The **Baseline** model overfits the most. The training accuracy climbs steeply while the validation accuracy plateaus and the loss diverges — a classic overfitting signature.
#
# **2. Did augmentation alone help?**
# Yes. By exposing the model to rotated, shifted, and flipped versions of the training images, augmentation makes it harder to memorize exact pixel patterns. The train/val accuracy gap is visibly reduced.
#
# **3. What effect did Dropout have?**
# Dropout lowers training accuracy (the network is harder to train) but improves or stabilizes validation accuracy. The training curve becomes noisier but the val curve is smoother and higher than the baseline.
#
# **4. Does BatchNorm speed up training?**
# Yes — the model with BatchNorm typically reaches a comparable or better validation accuracy in fewer epochs because the normalized inputs allow the optimizer to find good weights faster.
#
# **5. Which model would you deploy?**
# The **Aug + BN + Dropout** model: it has the best generalization, most stable training, and all techniques are complementary with no significant cost at inference time.
#
# **6. Bonus — 10-class CIFAR-10**
# Changes needed:
# - Output layer: `Dense(10, activation='softmax')` instead of `Dense(1, activation='sigmoid')`
# - Loss: `categorical_crossentropy` instead of `binary_crossentropy`
# - Labels: one-hot encode with `to_categorical(y, 10)` instead of binary 0/1
#
# ```python
# # Output layer
# Dense(10, activation='softmax')
#
# # Compile
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# # Labels
# y_train_cat = to_categorical(y_train_all, 10)
# y_test_cat  = to_categorical(y_test_all,  10)
# ```
